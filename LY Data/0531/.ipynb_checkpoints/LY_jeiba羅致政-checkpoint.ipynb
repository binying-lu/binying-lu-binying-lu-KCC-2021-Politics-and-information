# %%
import pandas as pd
import jieba
import jieba.analyse
from tqdm import tqdm
import re
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

pd.set_option('display.max_colwidth', None)#setting the maximize string show

# %%
word = pd.read_csv('委員逐字稿.csv',encoding='utf-8') #匯資料
lin = word[word.Name == "林德福"]
#lin.head(1)

# %%
doc_names = range(len(lin)) #江啟臣有幾篇文章
doc_names
# Out:
# range(0, 699)

# %%
lin = lin.replace(np.nan, '', regex=True) #將nan取代成空白字串

text_list = list(lin['Speech'])
lin_docs = pd.DataFrame(columns=['jieba_results'])
lin_docs['jieba_results'] = lin_docs['jieba_results'].astype('str')

# %%
words = jieba.lcut(text_list[1], cut_all = False)
print(words)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/bb/vrfcp_x10vb62mbgn3fyfn640000gp/T/jieba.cache
# Loading model cost 0.613 seconds.
# Prefix dict has been built succesfully.
# ['\ufeff', '林委員', '德福', '：', '主席', '、', '各位', '列席', '官員', '、', '各位', '同仁', '。', '彭總裁', '於', ' ', '6', ' ', '月', '下旬', '表示', '，', '今', '（', '103', '）', '年', '下半年', '整體', '\n', '\n', '的', '經濟景氣', '將優', '於', '上半年', '，', '而且', '在', '全球', '經濟', '穩定', '成長', '的', '帶動', '下', '，', '當然', '有助', '於', '維', '繫', '我', '國', '出口', '的', '成長', '\n', '\n', '動能', '。', '請問', '彭總裁', '，', '既然', '國內', '景氣', '日漸', '復', '甦', '，', '一向', '被', '稱', '為', '「', '經濟', '櫥', '窗', '」', '的', '股市', '，', '最近', '表現', '持續量', '\n', '縮價', '跌', '，', '外資', '也', '持續', '賣超', '，', '到底', '是', '什麼', '原因', '所致', '？', '\n', '\n', '主席', '：', '請', '中央', '銀行', '彭總裁', '答', '復', '。', '\n', '\n', '彭總裁', '淮南', '：', '主席', '、', '各位', '委員', '。', '報告', '委員', '，', '臺', '灣', '股市', '從', '權量', '股票', '來', '看', '，', '外資', '占', '百分之三十五', '；', '從台', '\n', '股', '流量', '來', '看', '，', '以', '每日', '股市', '交易量', '有', '四分之一', '是', '由', '外資', '操作', '。', '外資自', ' ', '9', ' ', '月份', '起', '減少', '持有', '韓國', '與', '臺', '灣', '\n', '的', '股票', '，', '不過', '，', '從', '年初', '迄今', '這', '部分', '仍屬', '於', '淨', '流入', '。', '自', ' ', '9', ' ', '月份', '迄今', '，', '臺', '灣', '、', '香港', '與', '韓國', '的', '股市', '指數', '\n', '\n', '呈現', '下跌', '的', '現象', '；', '上海', '與', '東京', '股市', '則是', '上', '漲', '。', '持平', '而言', '，', '從', '年初', '到', '昨天', '，', '臺', '灣的', '股價', '還算', '不錯', '…', '\n', '…', '\n', '\n', '林委員', '德福', '：', '依總裁', '之見', '，', '最近', '台股', '的', '狀況', '究', '係', '屬', '於', '短期', '現象', '，', '還是', '預告', '未來', '整體', '經濟', '有', '反轉', '的', '警', '\n', '\n', '訊', '？', '\n', '\n', '彭總裁', '淮南', '：', '我們將', '上市', '（', '櫃', '）', '公司', '去年', '上半年', '與', '今年', '上半年', '的', '稅後盈餘', '相較', '，', '金額', '增加', '百分之二', '\n', '十一', '，', '相當', '於', ' ', '1', ',', '474', ' ', '億元', '。', '此外', '，', '臺', '灣', '上市公司', '的', '股票', '每年', '所發', '的', '現金', '股利', '相當', '不', '錯且', '穩定', '，', '這', '\n', '正是', '外資', '喜歡', '投資台', '股', '的', '原因', '，', '從', '基本面', '來', '看', '，', '台股', '算是', '不錯', '的', '。', '\n', '\n', '林委員', '德福', '：', '再', '請', '教', '彭總裁', '，', '最近', '日圓', '一再', '貶值', '，', '但是', '國內', '有', '許多', '進口', '的', '日', '貨並', '沒有', '因日圓', '貶值', '而', '\n', '\n', '降價', '，', '其', '原因', '為何', '？', '\n', '\n', '彭總裁', '淮南', '：', '我', '認為', '匯率', '貶值', '與', '日貨', '商品', '降價會', '相隔', '一段', '時間', '，', '通常', '店家', '都', '會', '說', '：', '「', '這些', '都', '是', '我', '以', '\n', '\n', '前', '進口', '的', '貨品', '。', '」', '隔', '一段', '時間', '，', '商家', '應該', '會', '合理', '反映', '匯率', '。', '事實', '上', '，', '在', '日圓', '貶值', '的', '背後是', '有', '一股', '\n', '力量', '，', '背', '後', '最大', '的', '力量', '正是', '日本政府', '投資', '的', '退休', '基金', '，', '其', '基金', '規模', '高達', ' ', '1.26', ' ', '兆', '美金', '，', '主要', '希望', '\n', '減少', '日本', '公債', '及', '增加', '國外', '股票', '投資', '，', '正因如此', '，', '他們', '把', '錢', '趕', '出去', '，', '日圓', '當然', '就', '會', '貶值', '。', '\n', '\n', '林委員', '德福', '：', '原來', '如此', '。', '再', '請', '教總裁', '的', '問題', '是', '，', '根據', '媒體', '報導', '，', '在', ' ', 'G20', ' ', '財經', '首長', '會議', '中', '，', '針對', '近', '\n', '\n', '幾個', '月', '經濟', '風險', '不斷', '升高', '而', '提出', '警訊', '。', '依總裁', '之見', '，', '到底', '有', '哪些', '原因', '導致', '近來', '全球', '經濟', '風險', '升高', '\n', '？', '\n', '\n', '彭總裁', '淮南', '：', '我', '看到', ' ', '9', ' ', '月', ' ', '21', ' ', '日', '所', '刊登', '的', '公報', '載明', '，', '在', '歐洲', '召開', ' ', 'G20', ' ', '財經', '首長', '會議', '所', '提到', '的', '解決方', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '法', '，', '就是', '各國', '加速', '基礎', '建設', '投資', '。', '\n', '\n', '林委員', '德福', '：', '你', '認為', '這會', '不會', '變成', '擴大', '的', '系', '統性', '風險', '？', '\n', '\n', '彭總裁', '淮南', '：', '我剛', '才', '已', '經報', '告過', '。', '現金', '世界', '上', '幾個', '主要', '國家', '的', '貨幣', '政策', '立場', '是', '有點', '背道', '而', '馳', '的', '，', '美', '\n', '國', '、', '英國', '採取', '緊縮', '政策', '，', '日本', '、', 'ECB', ' ', '還有', '中國', '大陸則', '是', '走', '寬', '鬆', '的', '貨', '幣', '政策', '，', '這些', '方向', '是', '不同', '的', '\n', '。', '\n', '\n', '林委員', '德福', '：', '那', '你', '認為', '短期', '內', '對', '台灣會', '造成', '哪些', '影響', '？', '\n', '\n', '彭總裁', '淮南', '：', '台灣', '受美國', '的', '影響', '會', '比', '較', '大', '，', '因為', '我們', '十年', '期公債', '的', '殖', '利率', '，', '根本就是', '反映', '美國', ...

# %%
punctuation = "、，：:""()\n!！？｡＂＃＄％＆＇（）＊＋－／：；＜＝＞＠［＼］＾＿｀｛｜｝～｟｠｢｣､、〃》「」『』【】〔〕〖〗〘〙〚〛〜〝〞〟〰〾〿–—‘'‛“”„‟…‧﹏"""
re_punctuation = "[{}] ".format(punctuation)

jieba.set_dictionary("dict.big.txt")

# creat a df to store the jieba result
lin_docs = pd.DataFrame(columns=['jieba_results']) # 建立df
lin_docs['jieba_results'] =lin_docs['jieba_results'].astype('str')

for i in doc_names: #從第一篇到最後一篇
    words = jieba.cut(text_list[i], cut_all = False)
    text = ''
    for word in words:
        text = text + ' ' + str(word) 
    #print(words)
    #print(i) #第幾篇文章
    #print(text) #第幾篇文章的斷詞結果
    text = re.sub(re_punctuation, "", text) # 把上面那些符號從text中刪掉

#刪除文字 更多標點符號
    text = re.sub(r'[-<>#。！⋯.➡?=&▶_%♀!❗🎉⏰💪]','',text)  # 注意裡面不能有空白！
    lin = lin.replace(r'\\n','', regex=True)
    s = pd.Series({'jieba_results': text})
    lin_docs = lin_docs.append(s, ignore_index=True)#每次的斷詞結果都加回jiang_docs
# Out:
# Building prefix dict from /Users/Binying/Documents/GitHub/KCC-2021-Politics-and-information/KCC Data/LY Data/0531/dict.big.txt ...
# Loading model from cache /var/folders/bb/vrfcp_x10vb62mbgn3fyfn640000gp/T/jieba.u9f08b86761ca9ce850dcdbc28fab4ef6.cache
# Loading model cost 1.120 seconds.
# Prefix dict has been built succesfully.
